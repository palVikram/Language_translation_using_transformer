# %%
# !pip install tensorflow_datasets
# !pip install tensorflow-text
# Out:
# Requirement already satisfied: tensorflow_datasets in c:\users\14373\anaconda3\lib\site-packages (4.3.0)
# Requirement already satisfied: protobuf>=3.12.2 in c:\users\14373\anaconda3\lib\site-packages (from tensorflow_datasets) (3.12.2)
# Requirement already satisfied: importlib-resources; python_version < "3.9" in c:\users\14373\anaconda3\lib\site-packages (from tensorflow_datasets) (5.1.4)
# Requirement already satisfied: tqdm in c:\users\14373\anaconda3\lib\site-packages (from tensorflow_datasets) (4.42.1)
# Requirement already satisfied: numpy in c:\users\14373\anaconda3\lib\site-packages (from tensorflow_datasets) (1.19.5)
# Requirement already satisfied: promise in c:\users\14373\anaconda3\lib\site-packages (from tensorflow_datasets) (2.3)
# Requirement already satisfied: attrs>=18.1.0 in c:\users\14373\anaconda3\lib\site-packages (from tensorflow_datasets) (19.3.0)
# Requirement already satisfied: tensorflow-metadata in c:\users\14373\anaconda3\lib\site-packages (from tensorflow_datasets) (1.0.0)
# Requirement already satisfied: requests>=2.19.0 in c:\users\14373\anaconda3\lib\site-packages (from tensorflow_datasets) (2.24.0)
# Requirement already satisfied: dill in c:\users\14373\anaconda3\lib\site-packages (from tensorflow_datasets) (0.3.3)
# Requirement already satisfied: termcolor in c:\users\14373\anaconda3\lib\site-packages (from tensorflow_datasets) (1.1.0)
# Requirement already satisfied: typing-extensions; python_version < "3.8" in c:\users\14373\anaconda3\lib\site-packages (from tensorflow_datasets) (3.10.0.0)
# Requirement already satisfied: six in c:\users\14373\anaconda3\lib\site-packages (from tensorflow_datasets) (1.14.0)
# Requirement already satisfied: future in c:\users\14373\anaconda3\lib\site-packages (from tensorflow_datasets) (0.18.2)
# Requirement already satisfied: absl-py in c:\users\14373\anaconda3\lib\site-packages (from tensorflow_datasets) (0.9.0)
# Requirement already satisfied: setuptools in c:\users\14373\anaconda3\lib\site-packages (from protobuf>=3.12.2->tensorflow_datasets) (45.2.0.post20200210)
# Requirement already satisfied: zipp>=3.1.0; python_version < "3.10" in c:\users\14373\anaconda3\lib\site-packages (from importlib-resources; python_version < "3.9"->tensorflow_datasets) (3.4.1)
# Requirement already satisfied: googleapis-common-protos<2,>=1.52.0 in c:\users\14373\anaconda3\lib\site-packages (from tensorflow-metadata->tensorflow_datasets) (1.53.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\14373\anaconda3\lib\site-packages (from requests>=2.19.0->tensorflow_datasets) (2019.11.28)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\14373\anaconda3\lib\site-packages (from requests>=2.19.0->tensorflow_datasets) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\14373\anaconda3\lib\site-packages (from requests>=2.19.0->tensorflow_datasets) (1.25.8)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\14373\anaconda3\lib\site-packages (from requests>=2.19.0->tensorflow_datasets) (2.8)
# Collecting tensorflow-text
#   Using cached tensorflow_text-2.5.0-cp37-cp37m-win_amd64.whl (2.1 MB)
# Collecting tensorflow<2.6,>=2.5.0
#   Using cached tensorflow-2.5.0-cp37-cp37m-win_amd64.whl (422.6 MB)
# Requirement already satisfied: tensorflow-hub>=0.8.0 in c:\users\14373\anaconda3\lib\site-packages (from tensorflow-text) (0.8.0)
# Requirement already satisfied: numpy~=1.19.2 in c:\users\14373\anaconda3\lib\site-packages (from tensorflow<2.6,>=2.5.0->tensorflow-text) (1.19.5)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in c:\users\14373\anaconda3\lib\site-packages (from tensorflow<2.6,>=2.5.0->tensorflow-text) (1.1.2)
# Collecting gast==0.4.0
#   Using cached gast-0.4.0-py3-none-any.whl (9.8 kB)
# Collecting typing-extensions~=3.7.4
#   Using cached typing_extensions-3.7.4.3-py3-none-any.whl (22 kB)
# Collecting h5py~=3.1.0
#   Using cached h5py-3.1.0-cp37-cp37m-win_amd64.whl (2.7 MB)
# Collecting absl-py~=0.10
#   Using cached absl_py-0.12.0-py3-none-any.whl (129 kB)
# Requirement already satisfied: google-pasta~=0.2 in c:\users\14373\anaconda3\lib\site-packages (from tensorflow<2.6,>=2.5.0->tensorflow-text) (0.2.0)
# Requirement already satisfied: protobuf>=3.9.2 in c:\users\14373\anaconda3\lib\site-packages (from tensorflow<2.6,>=2.5.0->tensorflow-text) (3.12.2)
# Collecting six~=1.15.0
#   Using cached six-1.15.0-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: astunparse~=1.6.3 in c:\users\14373\anaconda3\lib\site-packages (from tensorflow<2.6,>=2.5.0->tensorflow-text) (1.6.3)
# Collecting opt-einsum~=3.3.0
#   Using cached opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# Requirement already satisfied: termcolor~=1.1.0 in c:\users\14373\anaconda3\lib\site-packages (from tensorflow<2.6,>=2.5.0->tensorflow-text) (1.1.0)
# Processing c:\users\14373\appdata\local\pip\cache\wheels\62\76\4c\aa25851149f3f6d9785f6c869387ad82b3fd37582fa8147ac6\wrapt-1.12.1-cp37-cp37m-win_amd64.whl
# Collecting grpcio~=1.34.0
#   Using cached grpcio-1.34.1-cp37-cp37m-win_amd64.whl (2.9 MB)
# Collecting keras-nightly~=2.5.0.dev
#   Using cached keras_nightly-2.5.0.dev2021032900-py2.py3-none-any.whl (1.2 MB)
# Collecting flatbuffers~=1.12.0
#   Using cached flatbuffers-1.12-py2.py3-none-any.whl (15 kB)
# Collecting tensorflow-estimator<2.6.0,>=2.5.0rc0
#   Using cached tensorflow_estimator-2.5.0-py2.py3-none-any.whl (462 kB)
# Collecting wheel~=0.35
#   Using cached wheel-0.36.2-py2.py3-none-any.whl (35 kB)
# Collecting tensorboard~=2.5
#   Using cached tensorboard-2.5.0-py3-none-any.whl (6.0 MB)
# Collecting cached-property; python_version < "3.8"
#   Using cached cached_property-1.5.2-py2.py3-none-any.whl (7.6 kB)
# Requirement already satisfied: setuptools in c:\users\14373\anaconda3\lib\site-packages (from protobuf>=3.9.2->tensorflow<2.6,>=2.5.0->tensorflow-text) (45.2.0.post20200210)
# Collecting tensorboard-data-server<0.7.0,>=0.6.0
#   Using cached tensorboard_data_server-0.6.1-py3-none-any.whl (2.4 kB)
# Requirement already satisfied: werkzeug>=0.11.15 in c:\users\14373\anaconda3\lib\site-packages (from tensorboard~=2.5->tensorflow<2.6,>=2.5.0->tensorflow-text) (1.0.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\14373\anaconda3\lib\site-packages (from tensorboard~=2.5->tensorflow<2.6,>=2.5.0->tensorflow-text) (1.7.0)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\14373\anaconda3\lib\site-packages (from tensorboard~=2.5->tensorflow<2.6,>=2.5.0->tensorflow-text) (2.24.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\14373\anaconda3\lib\site-packages (from tensorboard~=2.5->tensorflow<2.6,>=2.5.0->tensorflow-text) (0.4.1)
# Requirement already satisfied: google-auth<2,>=1.6.3 in c:\users\14373\anaconda3\lib\site-packages (from tensorboard~=2.5->tensorflow<2.6,>=2.5.0->tensorflow-text) (1.19.2)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\14373\anaconda3\lib\site-packages (from tensorboard~=2.5->tensorflow<2.6,>=2.5.0->tensorflow-text) (3.2.2)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\14373\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow<2.6,>=2.5.0->tensorflow-text) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\14373\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow<2.6,>=2.5.0->tensorflow-text) (1.25.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\14373\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow<2.6,>=2.5.0->tensorflow-text) (2019.11.28)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\14373\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow<2.6,>=2.5.0->tensorflow-text) (2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\14373\anaconda3\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.5->tensorflow<2.6,>=2.5.0->tensorflow-text) (1.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3" in c:\users\14373\anaconda3\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow<2.6,>=2.5.0->tensorflow-text) (4.6)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\14373\anaconda3\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow<2.6,>=2.5.0->tensorflow-text) (4.1.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\14373\anaconda3\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow<2.6,>=2.5.0->tensorflow-text) (0.2.8)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in c:\users\14373\anaconda3\lib\site-packages (from markdown>=2.6.8->tensorboard~=2.5->tensorflow<2.6,>=2.5.0->tensorflow-text) (1.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\14373\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.5->tensorflow<2.6,>=2.5.0->tensorflow-text) (3.1.0)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\14373\anaconda3\lib\site-packages (from rsa<5,>=3.1.4; python_version >= "3"->google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow<2.6,>=2.5.0->tensorflow-text) (0.4.8)
# Requirement already satisfied: zipp>=0.5 in c:\users\14373\anaconda3\lib\site-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard~=2.5->tensorflow<2.6,>=2.5.0->tensorflow-text) (3.4.1)
# Installing collected packages: gast, typing-extensions, cached-property, h5py, six, absl-py, opt-einsum, wrapt, grpcio, keras-nightly, flatbuffers, tensorflow-estimator, wheel, tensorboard-data-server, tensorboard, tensorflow, tensorflow-text
#   Attempting uninstall: gast
#     Found existing installation: gast 0.3.3
#     Uninstalling gast-0.3.3:
#       Successfully uninstalled gast-0.3.3
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing-extensions 3.10.0.0
#     Uninstalling typing-extensions-3.10.0.0:
#       Successfully uninstalled typing-extensions-3.10.0.0
#   Attempting uninstall: h5py
#     Found existing installation: h5py 2.10.0
#     Uninstalling h5py-2.10.0:
#       Successfully uninstalled h5py-2.10.0
#   Attempting uninstall: six
#     Found existing installation: six 1.14.0
#     Uninstalling six-1.14.0:
#       Successfully uninstalled six-1.14.0
#   Attempting uninstall: absl-py
#     Found existing installation: absl-py 0.9.0
#     Uninstalling absl-py-0.9.0:
#       Successfully uninstalled absl-py-0.9.0
#   Attempting uninstall: opt-einsum
#     Found existing installation: opt-einsum 3.2.1
#     Uninstalling opt-einsum-3.2.1:
#       Successfully uninstalled opt-einsum-3.2.1
#   Attempting uninstall: wrapt
#     Found existing installation: wrapt 1.11.2
#     Uninstalling wrapt-1.11.2:
#       Successfully uninstalled wrapt-1.11.2
#   Attempting uninstall: grpcio
#     Found existing installation: grpcio 1.30.0
#     Uninstalling grpcio-1.30.0:
#       Successfully uninstalled grpcio-1.30.0
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.3.0
#     Uninstalling tensorflow-estimator-2.3.0:
#       Successfully uninstalled tensorflow-estimator-2.3.0
#   Attempting uninstall: wheel
#     Found existing installation: wheel 0.34.2
#     Uninstalling wheel-0.34.2:
#       Successfully uninstalled wheel-0.34.2
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.3.0
#     Uninstalling tensorboard-2.3.0:
#       Successfully uninstalled tensorboard-2.3.0
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.3.0
#     Uninstalling tensorflow-2.3.0:
#       Successfully uninstalled tensorflow-2.3.0
# Successfully installed absl-py-0.12.0 cached-property-1.5.2 flatbuffers-1.12 gast-0.4.0 grpcio-1.34.1 h5py-3.1.0 keras-nightly-2.5.0.dev2021032900 opt-einsum-3.3.0 six-1.15.0 tensorboard-2.5.0 tensorboard-data-server-0.6.1 tensorflow-2.5.0 tensorflow-estimator-2.5.0 tensorflow-text-2.5.0 typing-extensions-3.7.4.3 wheel-0.36.2 wrapt-1.12.1
# ERROR: pytest-astropy 0.8.0 requires pytest-cov>=2.0, which is not installed.
# ERROR: pytest-astropy 0.8.0 requires pytest-filter-subpackage>=0.1, which is not installed.
# ERROR: astroid 2.3.3 requires typed-ast<1.5,>=1.4.0; implementation_name == "cpython" and python_version < "3.8", which is not installed.
# ERROR: tensorflow-gpu 2.1.0 has requirement gast==0.2.2, but you'll have gast 0.4.0 which is incompatible.
# ERROR: tensorflow-gpu 2.1.0 has requirement tensorboard<2.2.0,>=2.1.0, but you'll have tensorboard 2.5.0 which is incompatible.
# ERROR: rasa 1.10.8 has requirement absl-py<0.10,>=0.9, but you'll have absl-py 0.12.0 which is incompatible.
# ERROR: rasa 1.10.8 has requirement networkx<2.5.0,>=2.4.0, but you'll have networkx 2.3 which is incompatible.
# ERROR: rasa 1.10.8 has requirement packaging<21.0,>=20.0, but you'll have packaging 19.2 which is incompatible.
# ERROR: rasa 1.10.8 has requirement pika<1.2.0,>=1.1.0, but you'll have pika 1.0.1 which is incompatible.
# ERROR: rasa 1.10.8 has requirement ruamel.yaml<0.17,>=0.16, but you'll have ruamel-yaml 0.15.87 which is incompatible.
# ERROR: rasa 1.10.8 has requirement scikit-learn<0.23,>=0.22, but you'll have scikit-learn 0.20.4 which is incompatible.
# ERROR: rasa 1.10.8 has requirement slackclient<3.0.0,>=2.0.0, but you'll have slackclient 1.3.2 which is incompatible.
# ERROR: rasa 1.10.8 has requirement tensorflow<2.2,>=2.1, but you'll have tensorflow 2.5.0 which is incompatible.
# ERROR: rasa 1.10.8 has requirement tensorflow-estimator==2.1.0, but you'll have tensorflow-estimator 2.5.0 which is incompatible.
# ERROR: astroid 2.3.3 has requirement wrapt==1.11.*, but you'll have wrapt 1.12.1 which is incompatible.

# %%
import collections
import logging
import os
import pathlib
import re
import string
import sys
import time

import numpy as np
import matplotlib.pyplot as plt

import tensorflow_datasets as tfds
import tensorflow_text as text
import tensorflow as tf
logging.getLogger('tensorflow').setLevel(logging.ERROR)  # suppress warnings
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-a49ddac07849> in <module>
#      11 import matplotlib.pyplot as plt
#      12
# ---> 13 import tensorflow_datasets as tfds
#      14 import tensorflow_text as text
#      15 import tensorflow as tf
#
# ~\anaconda3\lib\site-packages\tensorflow_datasets\__init__.py in <module>
#      41 # needs to happen before anything else, since the imports below will try to
#      42 # import tensorflow, too.
# ---> 43 from tensorflow_datasets.core import tf_compat
#      44 tf_compat.ensure_tf_install()
#      45
#
# ~\anaconda3\lib\site-packages\tensorflow_datasets\core\__init__.py in <module>
#      23 # pylint:disable=g-import-not-at-top
#      24
# ---> 25 from tensorflow_datasets.core import community  # pylint: disable=g-bad-import-order
#      26
#      27 from tensorflow_datasets.core.constants import add_data_dir
#
# ~\anaconda3\lib\site-packages\tensorflow_datasets\core\community\__init__.py in <module>
#      16 """Community dataset API."""
#      17
# ---> 18 from tensorflow_datasets.core.community.huggingface_wrapper import mock_builtin_to_use_gfile
#      19 from tensorflow_datasets.core.community.huggingface_wrapper import mock_huggingface_import
#      20 from tensorflow_datasets.core.community.load import builder_cls_from_module
#
# ~\anaconda3\lib\site-packages\tensorflow_datasets\core\community\huggingface_wrapper.py in <module>
#      25 from unittest import mock
#      26
# ---> 27 import tensorflow as tf
#      28 from tensorflow_datasets.core import dataset_builder
#      29 from tensorflow_datasets.core import dataset_info
#
# ~\anaconda3\lib\site-packages\tensorflow\__init__.py in <module>
#      39 import sys as _sys
#      40
# ---> 41 from tensorflow.python.tools import module_util as _module_util
#      42 from tensorflow.python.util.lazy_loader import LazyLoader as _LazyLoader
#      43
#
# ~\anaconda3\lib\site-packages\tensorflow\python\__init__.py in <module>
#      46 from tensorflow.python import data
#      47 from tensorflow.python import distribute
# ---> 48 from tensorflow.python import keras
#      49 from tensorflow.python.feature_column import feature_column_lib as feature_column
#      50 from tensorflow.python.layers import layers
#
# ~\anaconda3\lib\site-packages\tensorflow\python\keras\__init__.py in <module>
#      23
#      24 # See b/110718070#comment18 for more details about this import.
# ---> 25 from tensorflow.python.keras import models
#      26
#      27 from tensorflow.python.keras.engine.input_layer import Input
#
# ~\anaconda3\lib\site-packages\tensorflow\python\keras\models.py in <module>
#      23 from tensorflow.python.keras.engine import sequential
#      24 from tensorflow.python.keras.engine import training
# ---> 25 from tensorflow.python.keras.engine import training_v1
#      26 from tensorflow.python.keras.engine.base_layer import AddMetric
#      27 from tensorflow.python.keras.engine.base_layer import Layer
#
# ~\anaconda3\lib\site-packages\tensorflow\python\keras\engine\training_v1.py in <module>
#      44 from tensorflow.python.keras.engine import base_layer
#      45 from tensorflow.python.keras.engine import training as training_lib
# ---> 46 from tensorflow.python.keras.engine import training_arrays_v1
#      47 from tensorflow.python.keras.engine import training_distributed_v1
#      48 from tensorflow.python.keras.engine import training_eager_v1
#
# ~\anaconda3\lib\site-packages\tensorflow\python\keras\engine\training_arrays_v1.py in <module>
#      35
#      36 try:
# ---> 37   from scipy.sparse import issparse  # pylint: disable=g-import-not-at-top
#      38 except ImportError:
#      39   issparse = None
#
# ~\anaconda3\lib\site-packages\scipy\sparse\__init__.py in <module>
#     227 import warnings as _warnings
#     228
# --> 229 from .base import *
#     230 from .csr import *
#     231 from .csc import *
#
# ~\anaconda3\lib\site-packages\scipy\sparse\base.py in <module>
#       5
#       6 from scipy._lib.six import xrange
# ----> 7 from scipy._lib._numpy_compat import broadcast_to
#       8 from .sputils import (isdense, isscalarlike, isintlike,
#       9                       get_sum_dtype, validateaxis, check_reshape_kwargs,
#
# ~\anaconda3\lib\site-packages\scipy\_lib\_numpy_compat.py in <module>
#      14
#      15 if NumpyVersion(np.__version__) > '1.7.0.dev':
# ---> 16     _assert_warns = np.testing.assert_warns
#      17 else:
#      18     def _assert_warns(warning_class, func, *args, **kw):
#
# ~\anaconda3\lib\site-packages\numpy\__init__.py in __getattr__(attr)
#     211                 from .testing import Tester
#     212                 return Tester
# --> 213             else:
#     214                 raise AttributeError("module {!r} has no attribute "
#     215                                      "{!r}".format(__name__, attr))
#
# ~\anaconda3\lib\site-packages\numpy\testing\__init__.py in <module>
#       8 from unittest import TestCase
#       9
# ---> 10 from ._private.utils import *
#      11 from ._private import decorators as dec
#      12 from ._private.nosetester import (
#
# ~\anaconda3\lib\site-packages\numpy\testing\_private\utils.py in <module>
#      50 IS_PYPY = platform.python_implementation() == 'PyPy'
#      51 HAS_REFCOUNT = getattr(sys, 'getrefcount', None) is not None
# ---> 52 HAS_LAPACK64 = numpy.linalg.lapack_lite._ilp64
#      53
#      54
#
# AttributeError: module 'numpy.linalg.lapack_lite' has no attribute '_ilp64'

# %%
examples, metadata = tfds.load('ted_hrlr_translate/pt_to_en', with_info=True,
                               as_supervised=True)

train_examples, val_examples = examples['train'], examples['validation']

# %%
for example_pr, example_en in train_examples.batch(4).take(1):
    for pt in example_pr.numpy():
        print(pt.decode("utf-8"))
        
    print()
    
    for en in example_en.numpy():
        print(en.decode("utf-8"))

# %%
model_name = "ted_hrlr_translate_pt_en_converter"
tf.keras.utils.get_file(
    f"{model_name}.zip",
    f"https://storage.googleapis.com/download.tensorflow.org/models/{model_name}.zip",
    cache_dir='.', cache_subdir='', extract=True
)

tokenizers = tf.saved_model.load(model_name)


[item for item in dir(tokenizers.en) if not item.startswith('_')]

# %%
for en in example_en.numpy():
  print(en.decode('utf-8'))
  
  
encoded=tokenizers.en.tokenize(example_en)

for row in encoded.to_list():
    print(row)
    
    
detokenizer=tokenizers.en.detokenize(encoded)

for line in detokenizer.numpy():
    print(line.decode('utf-8'))
    
    
token=tokenizers.en.lookup(encoded)

token

# %%
def tokenize_pair(en,pt):
    pt=tokenizers.pt.tokenize(pt)
    #convert ragged to dense by adding padding with zero
